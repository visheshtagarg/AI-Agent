# %% [markdown]
# # LoRA Fine-tuning Notebook (skeleton)
# This notebook shows a skeleton for LoRA fine-tuning of a seq2seq or encoder model for mapping user constraints to meal plans. Run in Colab/GPU.

# %%
# %pip install -q transformers peft datasets accelerate bitsandbytes

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, TrainingArguments, Trainer
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

# %%
# Load or create dataset - columns: input_text, target_text
# dataset = load_dataset('csv', data_files={'train':'data/train.csv','validation':'data/val.csv'})
print('Prepare dataset and tokenizers here')
